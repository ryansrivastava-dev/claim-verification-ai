# %% [markdown]
# # 04 Error Analysis
#
# Review incorrect predictions and categorize errors.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
error_path = ROOT / "data" / "processed" / "error_analysis_sample.csv"
if not error_path.exists():
    print("Run: python src/error_analysis.py")
else:
    errors = pd.read_csv(error_path)
    display(errors.head(10))

# %%
if error_path.exists():
    errors["likely_error_type"].value_counts(dropna=False).plot(kind="bar", title="Error type counts")

# %% [markdown]
# ## Common failure types
#
# Use this section to write observations after manual review. Focus on retrieval failures, label confusion, ambiguity, and insufficient evidence.
